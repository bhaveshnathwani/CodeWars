# %% [markdown]
# # Write Number in Expanded Form

# %% [markdown]
# __Latest Update:__ 15-10-19
# <br>
# __Author:__ Bhavesh Nathwani

# %% [markdown]
# ### The Challenge:
# https://www.codewars.com/kata/write-number-in-expanded-form/train/python
# <br>
# <br>
# **Description:**
# Write Number in Expanded Form
# <br>
# You will be given a number and you will need to return it as a string in Expanded Form. For example:
# <br>
# <br>
# **Examples:**
# <br>
# expanded_form(12) # Should return '10 + 2'
# <br>
# expanded_form(42) # Should return '40 + 2'
# <br>
# expanded_form(70304) # Should return '70000 + 300 + 4'
# <br>
# <br>
# **Note:** All numbers will be whole numbers greater than 0.

# %%
def expanded_form(num):
    number = []
    zero = []
    string = []
    string2 = []
    
    for zeros, numbers in list(enumerate(reversed(str(num)))):
        zero.append(zeros)
        number.append(numbers)
    
    for i in range(len(number)):
        string.append(number[i]+"0"*zero[i])
    
    for i in string:
        if "0" * len(i) != i:
            string2.append(i)

    return " + ".join(string2[::-1])

# %% [markdown]
# ### Testing with random integars:

# %%
import random

test_list = [random.randint(0,1000) for i in range(100)]

for i in range(len(test_list)):
    print("'{}' returns {}".format(test_list[i], expanded_form(test_list[i])))
# Out:
# '583' returns 500 + 80 + 3
# '157' returns 100 + 50 + 7
# '141' returns 100 + 40 + 1
# '208' returns 200 + 8
# '764' returns 700 + 60 + 4
# '603' returns 600 + 3
# '120' returns 100 + 20
# '292' returns 200 + 90 + 2
# '535' returns 500 + 30 + 5
# '467' returns 400 + 60 + 7
# '844' returns 800 + 40 + 4
# '729' returns 700 + 20 + 9
# '668' returns 600 + 60 + 8
# '183' returns 100 + 80 + 3
# '343' returns 300 + 40 + 3
# '87' returns 80 + 7
# '953' returns 900 + 50 + 3
# '828' returns 800 + 20 + 8
# '686' returns 600 + 80 + 6
# '233' returns 200 + 30 + 3
# '140' returns 100 + 40
# '492' returns 400 + 90 + 2
# '645' returns 600 + 40 + 5
# '959' returns 900 + 50 + 9
# '175' returns 100 + 70 + 5
# '649' returns 600 + 40 + 9
# '934' returns 900 + 30 + 4
# '287' returns 200 + 80 + 7
# '271' returns 200 + 70 + 1
# '196' returns 100 + 90 + 6
# '445' returns 400 + 40 + 5
# '822' returns 800 + 20 + 2
# '204' returns 200 + 4
# '139' returns 100 + 30 + 9
# '677' returns 600 + 70 + 7
# '105' returns 100 + 5
# '342' returns 300 + 40 + 2
# '999' returns 900 + 90 + 9
# '754' returns 700 + 50 + 4
# '283' returns 200 + 80 + 3
# '882' returns 800 + 80 + 2
# '291' returns 200 + 90 + 1
# '113' returns 100 + 10 + 3
# '778' returns 700 + 70 + 8
# '222' returns 200 + 20 + 2
# '705' returns 700 + 5
# '314' returns 300 + 10 + 4
# '1000' returns 1000
# '41' returns 40 + 1
# '815' returns 800 + 10 + 5
# '87' returns 80 + 7
# '959' returns 900 + 50 + 9
# '987' returns 900 + 80 + 7
# '527' returns 500 + 20 + 7
# '108' returns 100 + 8
# '835' returns 800 + 30 + 5
# '829' returns 800 + 20 + 9
# '561' returns 500 + 60 + 1
# '202' returns 200 + 2
# '960' returns 900 + 60
# '359' returns 300 + 50 + 9
# '172' returns 100 + 70 + 2
# '455' returns 400 + 50 + 5
# '708' returns 700 + 8
# '595' returns 500 + 90 + 5
# '542' returns 500 + 40 + 2
# '558' returns 500 + 50 + 8
# '767' returns 700 + 60 + 7
# '368' returns 300 + 60 + 8
# '891' returns 800 + 90 + 1
# '968' returns 900 + 60 + 8
# '947' returns 900 + 40 + 7
# '166' returns 100 + 60 + 6
# '391' returns 300 + 90 + 1
# '895' returns 800 + 90 + 5
# '193' returns 100 + 90 + 3
# '434' returns 400 + 30 + 4
# '409' returns 400 + 9
# '672' returns 600 + 70 + 2
# '609' returns 600 + 9
# '528' returns 500 + 20 + 8
# '583' returns 500 + 80 + 3
# '374' returns 300 + 70 + 4
# '422' returns 400 + 20 + 2
# '842' returns 800 + 40 + 2
# '231' returns 200 + 30 + 1
# '626' returns 600 + 20 + 6
# '71' returns 70 + 1
# '841' returns 800 + 40 + 1
# '597' returns 500 + 90 + 7
# '465' returns 400 + 60 + 5
# '771' returns 700 + 70 + 1
# '525' returns 500 + 20 + 5
# '857' returns 800 + 50 + 7
# '143' returns 100 + 40 + 3
# '674' returns 600 + 70 + 4
# '503' returns 500 + 3
# '45' returns 40 + 5
# '383' returns 300 + 80 + 3
# '976' returns 900 + 70 + 6
