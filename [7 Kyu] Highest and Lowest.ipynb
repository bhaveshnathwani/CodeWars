# %% [markdown]
# # Highest and Lowest

# %% [markdown]
# __Latest Update:__ 22-10-19
# <br>
# __Author:__ Bhavesh Nathwani

# %% [markdown]
# ### The Challenge:
# https://www.codewars.com/kata/highest-and-lowest/train/python
# <br>
# <br>
# **Description:**
# In this little assignment you are given a string of space separated numbers, and have to return the highest and lowest number.
# <br>
# <br>
# **Examples:**
# <br>
# high_and_low("1 2 3 4 5")  # return "5 1"
# <br>
# high_and_low("1 2 -3 4 5") # return "5 -3"
# <br>
# high_and_low("1 9 3 4 -5") # return "9 -5"
# <br>
# <br>
# **NOTES:**
# <br>
# All numbers are valid Int32, no need to validate them.
# <br>
# There will always be at least one number in the input string.
# <br>
# Output string must be two numbers separated by a single space, and highest number is first.

# %%
def high_and_low(numbers):
    numbers_int = [int(x) for x in numbers.split(" ")]
    return "{} {}".format(max(numbers_int), min(numbers_int))

# %% [markdown]
# ### Testing with random integars:

# %%
import random

for i in range(500):
    test_string =   str(random.randint(-1000,1000)) + " " + \
                    str(random.randint(-1000,1000)) + " " + \
                    str(random.randint(-1000,1000)) + " " + \
                    str(random.randint(-1000,1000)) + " " + \
                    str(random.randint(-1000,1000)) + " " + \
                    str(random.randint(-1000,1000)) 
    print("'{}' returns {}".format(test_string, high_and_low(test_string)))
# Out:
# '866 514 -360 -262 353 -767' returns 866 -767
# '481 977 -983 -58 -566 343' returns 977 -983
# '-402 -842 -320 -842 620 870' returns 870 -842
# '941 236 -620 359 -201 871' returns 941 -620
# '335 -361 -653 20 719 -307' returns 719 -653
# '-148 -378 463 -188 -43 506' returns 506 -378
# '216 -464 -704 -783 -653 -94' returns 216 -783
# '874 -147 -177 333 -797 610' returns 874 -797
# '-54 -766 857 509 -856 805' returns 857 -856
# '815 995 -649 284 720 656' returns 995 -649
# '826 122 -147 606 -722 -192' returns 826 -722
# '-800 -891 98 -113 -707 179' returns 179 -891
# '-419 343 -265 363 856 -339' returns 856 -419
# '-449 160 35 -525 -949 259' returns 259 -949
# '-842 618 249 286 838 -73' returns 838 -842
# '-859 -933 -131 -778 -12 -927' returns -12 -933
# '745 413 552 -792 -238 304' returns 745 -792
# '-38 -851 -85 -159 -205 -759' returns -38 -851
# '-164 53 -606 77 -91 -826' returns 77 -826
# '743 -410 -685 636 916 845' returns 916 -685
# '234 894 697 501 -498 -948' returns 894 -948
# ...
