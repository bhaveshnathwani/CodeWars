# %% [markdown]
# # <font color=#C70039>Sum of Intervals</font>

# %% [markdown]
# __Latest Update:__ 16-10-19
# <br>
# __Author:__ Bhavesh Nathwani

# %% [markdown]
# ### <font color=#C70039>The Challenge:</font>
# https://www.codewars.com/kata/sum-of-intervals/train/python
# <br>
# <br>
# **Description:**
# <br>
# Write a function called sumIntervals/sum_intervals() that accepts an array of intervals, and returns the sum of all the interval lengths. Overlapping intervals should only be counted once.
# <br>
# <br>
# **Intervals**
# <br>
# Intervals are represented by a pair of integers in the form of an array. The first value of the interval will always be less than the second value. Interval example: [1, 5] is an interval from 1 to 5. The length of this interval is 4.
# <br>
# <br>
# **Overlapping Intervals**
# <br>
# List containing overlapping intervals:
# <br>
# [
#    [1,4],
#    [7, 10],
#    [3, 5]
# ]
# <br>
# The sum of the lengths of these intervals is 7. Since [1, 4] and [3, 5] overlap, we can treat the interval as [1, 5], which has a length of 4.
# <br>
# <br>
# **Examples:**
# <br>
# sumIntervals( [
#    [1,2],
#    [6, 10],
#    [11, 15]
# ] ); // => 9
# <br>
# sumIntervals( [
#    [1,4],
#    [7, 10],
#    [3, 5]
# ] ); // => 7
# <br>
# sumIntervals( [
#    [1,5],
#    [10, 20],
#    [1, 6],
#    [16, 19],
#    [5, 11]
# ] ); // => 19

# %%
from itertools import combinations 

def sum_of_intervals(intervals):
    for interval in intervals:
        interval.sort(reverse = False) 
        
    overlap = 0
    running_total = 0

    combination_list = combinations(intervals, 2)
    for i in combination_list:
        overlap += max(0, min(i[0][1], i[1][1]) - max(i[0][0], i[1][0]))

    for i in range(0, len(intervals)):
        running_total += (intervals[i][1] - intervals[i][0])

    running_total -= overlap

    return running_total

# %%
print(sum_of_intervals([]))

# %% [markdown]
# ### <font color=#C70039>Testing with random intervals:</font>

# %%
import random

test_intervals = []

#Randomly create 1,000 intervals
for i in range(1000):  
    test_intervals.append([random.randint(0,50) for i in range(2)])

#Randomly pick between 2 and 5 intervals from the pool of 1,000 intervals, and carry out test 500 times

for i in range(500):
    test_iteration = random.sample(test_intervals, random.randint(2,5))
    print("{} returns an overlap of {}".format(test_iteration, sum_of_intervals(test_iteration)))
# Out:
# [[26, 50], [30, 44], [5, 24], [39, 45], [6, 27]] returns an overlap of 40
# [[35, 43], [24, 48], [4, 36], [10, 27], [7, 21]] returns an overlap of 29
# [[25, 50], [31, 43], [26, 27], [7, 19], [8, 27]] returns an overlap of 42
# [[15, 49], [16, 24], [4, 14]] returns an overlap of 44
# [[27, 38], [17, 32], [1, 25], [22, 45], [27, 34]] returns an overlap of 24
# [[11, 34], [0, 22], [21, 48], [0, 31]] returns an overlap of 26
# [[10, 48], [9, 45], [18, 19]] returns an overlap of 38
# [[0, 28], [18, 24], [22, 35], [27, 50]] returns an overlap of 47
# [[11, 35], [12, 31], [35, 50]] returns an overlap of 39
# [[2, 9], [13, 32], [4, 21]] returns an overlap of 30
# [[28, 30], [17, 28], [10, 10], [2, 16], [5, 48]] returns an overlap of 46
# [[2, 48], [0, 17]] returns an overlap of 48
# [[10, 29], [18, 49], [35, 44], [23, 24], [37, 50]] returns an overlap of 32
# [[18, 26], [13, 45], [35, 42]] returns an overlap of 32
# [[17, 26], [33, 47]] returns an overlap of 23
# [[2, 48], [28, 33]] returns an overlap of 46
# [[30, 46], [0, 17], [1, 15]] returns an overlap of 33
# [[15, 22], [33, 38], [8, 14]] returns an overlap of 18
# [[19, 22], [4, 39], [7, 40], [26, 43], [5, 21]] returns an overlap of 7
# [[34, 45], [23, 36], [7, 14]] returns an overlap of 29
# [[15, 22], [12, 43], [26, 33], [26, 30]] returns an overlap of 27
# [[36, 49], [11, 48], [20, 34]] returns an overlap of 38
# [[0, 28], [42, 45], [17, 33]] returns an overlap of 36
# [[38, 48], [33, 45], [12, 23]] returns an overlap of 26
# [[6, 9], [18, 26], [27, 31], [31, 40], [16, 34]] returns an overlap of 27
# [[22, 46], [2, 34], [14, 49], [14, 19]] returns an overlap of 30
# [[9, 45], [17, 47], [13, 45], [13, 40]] returns an overlap of -40
# [[32, 33], [7, 37], [35, 46], [40, 45], [24, 39]] returns an overlap of 36
# [[10, 21], [2, 33]] returns an overlap of 31
# [[4, 38], [31, 43], [2, 8]] returns an overlap of 41
# [[29, 38], [30, 46]] returns an overlap of 17
# [[0, 37], [45, 49]] returns an overlap of 41
# [[33, 50], [1, 31], [13, 38], [27, 34]] returns an overlap of 44
# [[14, 22], [12, 32], [12, 34]] returns an overlap of 14
# [[18, 35], [17, 42], [27, 38], [19, 27]] returns an overlap of 9
# [[12, 47], [27, 49], [41, 42], [2, 45]] returns an overlap of 27
# [[17, 40], [21, 50]] returns an overlap of 33
# [[25, 36], [1, 25]] returns an overlap of 35
# [[38, 49], [28, 43]] returns an overlap of 21
# [[3, 24], [39, 45], [1, 29], [25, 29]] returns an overlap of 34
# [[8, 14], [6, 34], [42, 50]] returns an overlap of 36
# [[34, 48], [9, 18], [1, 29], [37, 40], [31, 32]] returns an overlap of 43
# [[20, 36], [33, 44], [5, 21]] returns an overlap of 39
# [[11, 39], [32, 38]] returns an overlap of 28
# [[7, 35], [15, 27]] returns an overlap of 28
# [[15, 41], [11, 11], [23, 37]] returns an overlap of 26
# [[35, 44], [24, 27], [17, 40], [27, 45], [0, 33]] returns an overlap of 31
# [[24, 34], [8, 14], [38, 45]] returns an overlap of 23
# [[37, 50], [37, 45], [8, 27], [2, 39]] returns an overlap of 46
# [[15, 49], [39, 40], [20, 40], [4, 34]] returns an overlap of 30
# [[14, 38], [2, 41]] returns an overlap of 39
# [[4, 22], [4, 34], [11, 23], [5, 47]] returns an overlap of 3
# [[9, 35], [11, 20], [3, 42]] returns an overlap of 30
# [[16, 25], [4, 33], [9, 40], [8, 14]] returns an overlap of 22
# [[34, 44], [26, 48], [25, 36]] returns an overlap of 21
# [[22, 28], [7, 40], [6, 38], [5, 12], [18, 29]] returns an overlap of 7
# [[12, 21], [30, 37], [32, 33], [10, 26]] returns an overlap of 23
# [[1, 8], [12, 47], [2, 7], [2, 22]] returns an overlap of 41
# [[4, 27], [20, 23], [14, 43]] returns an overlap of 36
# [[4, 22], [16, 24]] returns an overlap of 20
# [[8, 16], [44, 46]] returns an overlap of 10
# [[23, 37], [7, 24], [20, 30]] returns an overlap of 29
# [[7, 37], [38, 41], [0, 32], [5, 50], [21, 23]] returns an overlap of 21
# [[39, 45], [10, 30], [18, 41], [34, 50], [7, 27]] returns an overlap of 32
# [[12, 31], [33, 46], [14, 38], [27, 40], [6, 38]] returns an overlap of -2
# [[24, 25], [10, 17], [16, 25], [7, 34], [8, 15]] returns an overlap of 20
# [[27, 28], [25, 50], [5, 5], [1, 20], [33, 47]] returns an overlap of 44
# [[26, 30], [18, 35], [24, 50], [31, 40], [1, 4]] returns an overlap of 27
# [[13, 20], [28, 49]] returns an overlap of 28
# [[9, 28], [0, 1], [29, 40]] returns an overlap of 31
# [[11, 20], [9, 49], [2, 49]] returns an overlap of 38
# [[33, 43], [50, 50]] returns an overlap of 10
# [[26, 33], [28, 31], [8, 36]] returns an overlap of 25
# [[44, 48], [22, 26], [33, 38]] returns an overlap of 13
# [[10, 17], [16, 23], [13, 38]] returns an overlap of 27
# [[38, 50], [42, 46], [26, 33], [19, 27]] returns an overlap of 26
# [[25, 28], [18, 46], [11, 23]] returns an overlap of 35
# [[2, 42], [17, 41], [4, 12], [13, 40], [22, 39]] returns an overlap of -17
# [[1, 50], [15, 24], [11, 44]] returns an overlap of 40
# [[0, 6], [6, 37]] returns an overlap of 37
# [[19, 42], [23, 24], [1, 46], [14, 38], [10, 14]] returns an overlap of 24
# [[19, 42], [0, 43], [35, 44]] returns an overlap of 37
# [[22, 43], [10, 48], [12, 46]] returns an overlap of 17
# [[18, 45], [27, 31], [26, 31], [8, 23]] returns an overlap of 33
# [[4, 43], [27, 40]] returns an overlap of 39
# [[17, 19], [6, 22], [7, 37], [12, 21], [11, 20]] returns an overlap of -1
# [[35, 41], [31, 40], [13, 32], [11, 24], [10, 14]] returns an overlap of 30
# [[0, 9], [26, 27], [5, 11], [25, 30]] returns an overlap of 16
# [[7, 46], [29, 50], [20, 26], [2, 47]] returns an overlap of 25
# [[5, 29], [0, 16]] returns an overlap of 29
# [[29, 38], [2, 8], [28, 36], [25, 43], [16, 28]] returns an overlap of 26
# [[9, 33], [32, 41], [21, 30], [44, 46]] returns an overlap of 34
# [[17, 19], [30, 46], [44, 46]] returns an overlap of 18
# [[11, 21], [34, 50]] returns an overlap of 26
# [[16, 47], [11, 16]] returns an overlap of 36
# [[9, 31], [8, 41], [18, 24], [30, 46]] returns an overlap of 31
# [[18, 29], [0, 11], [2, 16], [13, 47]] returns an overlap of 47
# [[16, 27], [1, 29], [31, 47]] returns an overlap of 44
# [[39, 40], [24, 30], [24, 34], [8, 24], [16, 37]] returns an overlap of 24
# [[0, 44], [0, 30], [28, 41], [4, 42]] returns an overlap of 3
# [[21, 30], [18, 26], [22, 26]] returns an overlap of 8
# [[1, 47], [38, 44], [16, 48]] returns an overlap of 41
# [[18, 22], [0, 44], [39, 45]] returns an overlap of 45
# [[33, 43], [22, 26], [6, 22], [15, 41]] returns an overlap of 37
# [[31, 39], [25, 45], [27, 50]] returns an overlap of 17
# [[36, 50], [2, 9], [1, 37], [11, 11], [2, 7]] returns an overlap of 44
# [[44, 48], [11, 20], [2, 29], [4, 41], [19, 32]] returns an overlap of 23
# [[19, 42], [17, 18], [8, 41], [11, 48]] returns an overlap of 17
# [[40, 43], [7, 27], [14, 41], [7, 11]] returns an overlap of 36
# [[3, 25], [25, 43], [43, 44], [42, 45], [37, 45]] returns an overlap of 40
# [[23, 32], [8, 22]] returns an overlap of 23
# [[7, 11], [1, 8]] returns an overlap of 10
# [[17, 19], [4, 9], [4, 43], [8, 12]] returns an overlap of 38
# [[34, 50], [38, 49], [8, 22], [11, 34]] returns an overlap of 42
# [[5, 29], [9, 21], [15, 28]] returns an overlap of 18
# [[18, 24], [21, 50], [27, 36], [7, 17]] returns an overlap of 42
# [[11, 32], [41, 48], [45, 48], [0, 13]] returns an overlap of 39
# [[33, 44], [10, 50]] returns an overlap of 40
# [[8, 22], [18, 35], [0, 38], [27, 45], [9, 42]] returns an overlap of -8
# [[16, 21], [8, 14], [26, 41]] returns an overlap of 26
# [[27, 30], [16, 23], [0, 44], [0, 21]] returns an overlap of 39
# [[24, 27], [1, 42], [3, 31], [33, 48]] returns an overlap of 44
# [[11, 48], [31, 43], [0, 11], [19, 37], [41, 44]] returns an overlap of 40
# [[12, 23], [1, 29], [8, 47]] returns an overlap of 35
# [[22, 26], [1, 45], [32, 49], [30, 46], [36, 44]] returns an overlap of 19
# [[1, 28], [18, 24], [14, 43], [17, 18]] returns an overlap of 35
# [[16, 23], [38, 48]] returns an overlap of 17
# [[12, 34], [8, 27], [33, 36]] returns an overlap of 28
# [[5, 29], [3, 42], [0, 16], [27, 45]] returns an overlap of 32
# [[5, 21], [17, 41], [2, 26]] returns an overlap of 35
# [[28, 37], [10, 35]] returns an overlap of 27
# [[31, 39], [18, 28], [2, 16]] returns an overlap of 32
# [[6, 33], [18, 30], [36, 38], [2, 38], [16, 23]] returns an overlap of 12
# [[38, 48], [7, 20], [10, 31]] returns an overlap of 34
# [[38, 45], [25, 45], [5, 11], [8, 47], [20, 28]] returns an overlap of 32
# [[19, 42], [20, 28], [8, 29], [13, 45]] returns an overlap of 11
# [[11, 24], [8, 23], [16, 21], [5, 44]] returns an overlap of 17
# [[10, 48], [21, 48], [26, 31], [49, 50], [19, 38]] returns an overlap of 12
# [[22, 23], [21, 38]] returns an overlap of 17
# [[0, 31], [9, 50], [10, 14]] returns an overlap of 46
# [[10, 16], [13, 39]] returns an overlap of 29
# [[14, 24], [27, 28], [47, 50], [27, 34], [16, 24]] returns an overlap of 20
# [[4, 44], [24, 39], [11, 48], [20, 23], [17, 28]] returns an overlap of 8
# [[13, 33], [3, 33]] returns an overlap of 30
# [[19, 33], [5, 8], [26, 33]] returns an overlap of 17
# [[1, 45], [19, 22], [21, 30]] returns an overlap of 43
# [[2, 40], [8, 12], [26, 33], [46, 48], [6, 17]] returns an overlap of 36
# [[17, 47], [35, 44], [23, 25]] returns an overlap of 30
# [[7, 9], [3, 25], [15, 49]] returns an overlap of 46
# [[2, 40], [17, 34], [10, 17], [31, 47], [9, 25]] returns an overlap of 27
# [[24, 30], [4, 27], [12, 34], [4, 9], [8, 18]] returns an overlap of 20
# [[12, 30], [39, 40], [28, 49]] returns an overlap of 37
# [[47, 50], [24, 30], [20, 28]] returns an overlap of 13
# [[26, 30], [4, 6], [4, 36], [31, 35]] returns an overlap of 32
# [[35, 36], [17, 18], [4, 27], [30, 46], [10, 30]] returns an overlap of 41
# [[0, 21], [6, 39], [0, 17]] returns an overlap of 28
# [[26, 41], [5, 12], [9, 12]] returns an overlap of 22
# [[2, 32], [17, 42], [7, 10]] returns an overlap of 40
# [[28, 44], [23, 35], [23, 48]] returns an overlap of 18
# [[18, 50], [20, 28], [5, 48], [25, 49]] returns an overlap of 11
# [[13, 38], [7, 33], [1, 24], [2, 33]] returns an overlap of -11
# [[24, 30], [16, 17], [11, 20]] returns an overlap of 15
# [[18, 45], [0, 14], [43, 48]] returns an overlap of 44
# [[23, 44], [21, 41], [28, 31], [30, 44], [2, 10]] returns an overlap of 16
# [[28, 49], [25, 28]] returns an overlap of 24
# [[13, 32], [21, 40], [7, 41], [13, 36]] returns an overlap of -11
# [[25, 38], [0, 5], [0, 33]] returns an overlap of 38
# [[17, 49], [0, 46], [33, 43], [24, 29], [36, 47]] returns an overlap of 17
# [[21, 30], [26, 30]] returns an overlap of 9
# [[1, 46], [4, 42]] returns an overlap of 45
# [[0, 5], [0, 5], [2, 47], [43, 46]] returns an overlap of 44
# [[5, 38], [12, 41], [21, 41], [3, 16]] returns an overlap of 17
# [[34, 45], [28, 40], [8, 21]] returns an overlap of 30
# [[2, 8], [17, 18], [25, 45], [17, 34], [0, 28]] returns an overlap of 41
# [[15, 18], [9, 25], [23, 37], [21, 50], [33, 43]] returns an overlap of 35
# [[33, 49], [11, 48], [9, 17], [16, 34], [25, 38]] returns an overlap of 24
# [[26, 27], [5, 20], [8, 15], [20, 28]] returns an overlap of 23
# [[26, 37], [16, 48], [12, 12], [4, 6]] returns an overlap of 34
# [[28, 39], [3, 25], [9, 43], [39, 45], [30, 50]] returns an overlap of 34
# [[40, 45], [20, 38]] returns an overlap of 23
# [[7, 48], [20, 45]] returns an overlap of 41
# [[7, 35], [20, 26], [0, 46], [3, 20]] returns an overlap of 27
# [[16, 28], [14, 22]] returns an overlap of 14
# [[40, 49], [40, 45]] returns an overlap of 9
# [[45, 49], [20, 23]] returns an overlap of 7
# [[8, 14], [13, 40], [16, 24], [33, 41], [10, 38]] returns an overlap of 19
# [[2, 26], [6, 17]] returns an overlap of 24
# [[20, 30], [15, 33], [9, 16]] returns an overlap of 24
# [[1, 41], [7, 33], [11, 14], [0, 6], [28, 39]] returns an overlap of 33
# [[32, 39], [16, 31], [12, 31], [3, 24]] returns an overlap of 27
# [[23, 30], [2, 41]] returns an overlap of 39
# [[17, 18], [39, 45]] returns an overlap of 7
# [[17, 47], [28, 39]] returns an overlap of 30
# [[4, 33], [8, 47], [26, 31], [14, 20]] returns an overlap of 32
# [[18, 19], [16, 25], [33, 36], [42, 50]] returns an overlap of 20
# [[23, 44], [17, 18]] returns an overlap of 22
# [[13, 19], [27, 31], [30, 44], [28, 41]] returns an overlap of 22
# [[22, 43], [36, 40], [1, 42], [6, 33], [19, 32]] returns an overlap of 4
# [[3, 46], [4, 22]] returns an overlap of 43
# [[34, 37], [4, 12], [41, 44], [31, 44]] returns an overlap of 21
# [[14, 20], [25, 45]] returns an overlap of 26
# [[13, 38], [23, 44], [20, 50], [8, 21], [13, 19]] returns an overlap of 20
# [[22, 43], [22, 23], [5, 31]] returns an overlap of 37
# [[6, 38], [12, 34]] returns an overlap of 32
# [[27, 28], [1, 25], [26, 35]] returns an overlap of 33
# [[10, 17], [21, 48]] returns an overlap of 34
# [[19, 49], [1, 44], [43, 46], [33, 44], [10, 14]] returns an overlap of 35
# [[1, 42], [0, 4], [2, 30], [13, 47]] returns an overlap of 28
# [[11, 34], [8, 33], [2, 18], [7, 43], [1, 41]] returns an overlap of -56
# [[1, 2], [26, 41], [4, 48]] returns an overlap of 45
# [[21, 22], [2, 42], [11, 22], [9, 39], [27, 28]] returns an overlap of 26
# [[11, 22], [15, 34]] returns an overlap of 23
# [[7, 13], [11, 32], [9, 49]] returns an overlap of 40
# [[1, 19], [24, 30], [25, 45], [6, 12], [15, 27]] returns an overlap of 42
# [[12, 21], [7, 27]] returns an overlap of 20
# [[20, 43], [18, 26]] returns an overlap of 25
# [[10, 46], [15, 49], [19, 32], [21, 44]] returns an overlap of -8
# [[24, 25], [10, 26], [4, 45]] returns an overlap of 40
# [[11, 48], [9, 40], [23, 29]] returns an overlap of 33
# [[8, 38], [5, 8], [42, 45]] returns an overlap of 36
# [[43, 48], [33, 48], [32, 38]] returns an overlap of 16
# [[4, 29], [5, 8], [19, 25]] returns an overlap of 25
# [[8, 44], [19, 33]] returns an overlap of 36
# [[28, 29], [27, 48], [24, 34], [6, 17]] returns an overlap of 34
# [[5, 36], [16, 34]] returns an overlap of 31
# [[11, 23], [9, 29], [25, 41]] returns an overlap of 32
# [[9, 28], [12, 23], [7, 48]] returns an overlap of 30
# [[4, 41], [11, 41], [13, 50], [6, 17], [19, 33]] returns an overlap of -20
# [[9, 49], [2, 40], [15, 32]] returns an overlap of 30
# [[9, 45], [5, 23], [11, 23], [34, 44], [27, 44]] returns an overlap of 18
# [[8, 15], [8, 23], [11, 34], [32, 48]] returns an overlap of 36
# [[31, 41], [10, 29], [25, 39], [41, 48]] returns an overlap of 38
# [[31, 41], [23, 25], [40, 46], [10, 36]] returns an overlap of 36
# [[9, 18], [33, 45], [0, 44], [34, 44], [26, 41]] returns an overlap of 20
# [[17, 32], [25, 38]] returns an overlap of 21
# [[1, 38], [28, 46], [10, 25]] returns an overlap of 45
# [[21, 44], [8, 15], [6, 17], [7, 23]] returns an overlap of 31
# [[2, 15], [9, 31]] returns an overlap of 29
# [[16, 25], [33, 47], [9, 29], [22, 48]] returns an overlap of 36
# [[8, 15], [25, 41]] returns an overlap of 23
# [[5, 18], [28, 39], [15, 48], [35, 40]] returns an overlap of 39
# [[48, 48], [27, 50]] returns an overlap of 23
# [[0, 22], [6, 22], [5, 34], [28, 36]] returns an overlap of 20
# [[9, 34], [11, 46], [7, 21], [17, 47]] returns an overlap of 9
# [[19, 42], [22, 32], [9, 34], [6, 24], [25, 38]] returns an overlap of 3
# [[7, 7], [31, 43]] returns an overlap of 12
# [[27, 30], [0, 44], [15, 31], [10, 14]] returns an overlap of 41
# [[20, 21], [16, 34], [0, 16], [4, 34], [1, 15]] returns an overlap of 22
# [[33, 49], [26, 31], [5, 21], [16, 21], [15, 41]] returns an overlap of 39
# [[1, 46], [46, 47], [3, 46], [13, 19]] returns an overlap of 40
# [[28, 31], [10, 31], [35, 35], [14, 49]] returns an overlap of 36
# [[8, 24], [2, 41], [4, 44], [2, 29], [24, 48]] returns an overlap of -33
# [[17, 28], [14, 31]] returns an overlap of 17
# [[4, 34], [18, 26], [12, 12]] returns an overlap of 30
# [[24, 40], [2, 26], [11, 20], [13, 42]] returns an overlap of 31
# [[0, 5], [8, 15]] returns an overlap of 12
# [[30, 46], [17, 34]] returns an overlap of 29
# [[7, 50], [9, 31], [25, 39]] returns an overlap of 37
# [[5, 20], [5, 11], [39, 49]] returns an overlap of 25
# [[1, 46], [25, 38], [6, 18]] returns an overlap of 45
# [[35, 35], [10, 11]] returns an overlap of 1
# [[32, 48], [2, 42]] returns an overlap of 46
# [[20, 36], [5, 44], [28, 39]] returns an overlap of 31
# [[19, 50], [12, 21]] returns an overlap of 38
# [[6, 18], [1, 19], [32, 43], [27, 30], [26, 43]] returns an overlap of 35
# [[9, 49], [25, 43], [20, 45], [25, 49], [23, 23]] returns an overlap of -16
# [[36, 40], [4, 11], [7, 8], [36, 38], [5, 18]] returns an overlap of 17
# [[3, 48], [11, 32]] returns an overlap of 45
# [[20, 30], [12, 31], [5, 15], [25, 43]] returns an overlap of 33
# [[41, 48], [0, 43]] returns an overlap of 48
# [[27, 50], [10, 14], [3, 13], [8, 27]] returns an overlap of 44
# [[5, 22], [20, 34], [11, 39], [6, 12], [7, 29]] returns an overlap of 6
# [[6, 22], [11, 23]] returns an overlap of 17
# [[21, 48], [20, 46], [12, 47], [11, 48], [4, 48]] returns an overlap of -121
# [[45, 48], [12, 12], [31, 41], [20, 23], [21, 43]] returns an overlap of 26
# [[5, 24], [5, 20], [23, 38], [9, 43]] returns an overlap of 26
# [[7, 8], [9, 20], [17, 41]] returns an overlap of 33
# [[16, 24], [17, 18]] returns an overlap of 8
# [[26, 33], [21, 50], [35, 50], [30, 50], [0, 46]] returns an overlap of -2
# [[5, 15], [22, 23], [7, 10], [1, 46], [11, 22]] returns an overlap of 38
# [[16, 27], [17, 28], [9, 45], [21, 41], [36, 38]] returns an overlap of 11
# [[28, 41], [5, 22], [0, 31]] returns an overlap of 41
# [[24, 49], [26, 33], [8, 33]] returns an overlap of 34
# [[6, 44], [7, 29]] returns an overlap of 38
# [[16, 27], [28, 49], [2, 9], [25, 45]] returns an overlap of 40
# [[0, 36], [9, 33]] returns an overlap of 36
# [[7, 49], [9, 24], [22, 27]] returns an overlap of 40
# [[20, 32], [3, 17], [24, 48], [8, 47]] returns an overlap of 37
# [[15, 31], [16, 31], [39, 49], [6, 17], [18, 35]] returns an overlap of 25
# [[24, 40], [11, 24], [0, 18], [24, 30]] returns an overlap of 40
# [[27, 45], [7, 27]] returns an overlap of 38
# [[47, 49], [1, 46], [16, 22], [12, 47]] returns an overlap of 42
# [[0, 30], [5, 12], [17, 32], [8, 16], [4, 46]] returns an overlap of 14
# [[8, 21], [30, 46]] returns an overlap of 29
# [[7, 10], [18, 24], [5, 22]] returns an overlap of 19
# [[0, 31], [18, 45], [36, 50], [10, 25]] returns an overlap of 43
# [[42, 43], [20, 31], [13, 27], [28, 39], [0, 20]] returns an overlap of 40
# [[10, 14], [23, 30]] returns an overlap of 11
# [[14, 20], [5, 12], [36, 42], [16, 26]] returns an overlap of 25
# [[11, 44], [0, 16]] returns an overlap of 44
# [[17, 18], [21, 43]] returns an overlap of 23
# [[10, 11], [25, 29], [35, 36]] returns an overlap of 6
# [[45, 45], [19, 32], [32, 37]] returns an overlap of 18
# [[6, 22], [3, 42], [31, 43]] returns an overlap of 40
# [[20, 38], [10, 21], [0, 27], [13, 38], [1, 50]] returns an overlap of -9
# [[4, 39], [2, 10], [19, 22], [1, 43]] returns an overlap of 33
# [[2, 45], [11, 44]] returns an overlap of 43
# [[14, 31], [10, 10], [24, 29], [11, 33]] returns an overlap of 17
# [[16, 32], [9, 21], [7, 33]] returns an overlap of 21
# [[18, 26], [23, 32]] returns an overlap of 14
# [[21, 41], [9, 21], [0, 4]] returns an overlap of 36
# [[25, 43], [17, 34]] returns an overlap of 26
# [[3, 9], [0, 32], [7, 33], [6, 24]] returns an overlap of 11
# [[18, 28], [34, 37]] returns an overlap of 13
# [[17, 49], [7, 11], [8, 14], [32, 33], [24, 40]] returns an overlap of 38
# [[8, 12], [18, 35], [22, 48]] returns an overlap of 34
# [[16, 48], [19, 33], [4, 6], [47, 49], [25, 43]] returns an overlap of 27
# [[36, 49], [25, 29]] returns an overlap of 17
# [[18, 30], [35, 36], [4, 11], [41, 44]] returns an overlap of 23
# [[0, 46], [27, 38], [33, 36], [7, 35]] returns an overlap of 33
# [[40, 45], [7, 33]] returns an overlap of 31
# [[3, 20], [28, 31], [18, 40]] returns an overlap of 37
# [[0, 31], [24, 33], [35, 40], [19, 42]] returns an overlap of 35
# [[3, 13], [8, 44], [13, 42], [6, 12]] returns an overlap of 37
# [[3, 6], [20, 34]] returns an overlap of 17
# [[1, 10], [8, 24], [19, 27]] returns an overlap of 26
# [[6, 44], [38, 48], [36, 50], [10, 17]] returns an overlap of 38
# [[14, 49], [46, 47], [3, 6], [18, 46]] returns an overlap of 38
# [[44, 46], [23, 30], [2, 10], [9, 42], [11, 32]] returns an overlap of 35
# [[8, 14], [9, 25]] returns an overlap of 17
# [[9, 21], [3, 42], [25, 45]] returns an overlap of 42
# [[19, 50], [9, 45]] returns an overlap of 41
# [[4, 11], [6, 8], [0, 44], [1, 8]] returns an overlap of 36
# [[18, 24], [2, 32], [26, 36]] returns an overlap of 34
# [[29, 40], [2, 8], [1, 43], [30, 36]] returns an overlap of 36
# [[6, 35], [30, 44]] returns an overlap of 38
# [[21, 41], [6, 40], [24, 27]] returns an overlap of 32
# [[45, 45], [8, 48], [7, 21], [13, 19], [33, 47]] returns an overlap of 35
# [[42, 50], [17, 42], [44, 48], [8, 12], [11, 20]] returns an overlap of 42
# [[18, 46], [1, 21], [8, 47], [17, 40], [28, 31]] returns an overlap of 11
# [[2, 48], [9, 50]] returns an overlap of 48
# [[5, 25], [12, 47], [8, 22], [13, 42]] returns an overlap of 11
# [[19, 25], [15, 22]] returns an overlap of 10
# [[17, 28], [31, 43], [0, 20], [39, 45]] returns an overlap of 42
# [[4, 33], [5, 22]] returns an overlap of 29
# [[23, 27], [6, 14], [9, 29]] returns an overlap of 23
# [[28, 39], [1, 46]] returns an overlap of 45
# [[28, 40], [11, 37], [26, 29], [9, 31], [31, 40]] returns an overlap of 18
# [[26, 41], [30, 42], [7, 23], [0, 15], [44, 46]] returns an overlap of 41
# [[13, 32], [2, 42]] returns an overlap of 40
# [[32, 41], [2, 26], [37, 41], [30, 50], [37, 47]] returns an overlap of 32
# [[9, 35], [39, 42], [27, 44], [3, 42], [37, 38]] returns an overlap of 29
# [[25, 36], [31, 32], [9, 25], [24, 29]] returns an overlap of 27
# [[0, 30], [46, 47]] returns an overlap of 31
# [[3, 38], [11, 48]] returns an overlap of 45
# [[31, 35], [3, 16], [14, 20], [7, 41], [26, 50]] returns an overlap of 41
# [[5, 21], [9, 45], [33, 47], [45, 48]] returns an overlap of 43
# [[2, 9], [19, 36]] returns an overlap of 24
# [[27, 50], [2, 40], [9, 45]] returns an overlap of 35
# [[18, 49], [5, 22], [12, 47]] returns an overlap of 40
# [[0, 18], [2, 25], [4, 36], [0, 9], [38, 46]] returns an overlap of 18
# [[11, 14], [5, 21], [4, 7]] returns an overlap of 17
# [[27, 30], [2, 45], [32, 41]] returns an overlap of 43
# [[27, 50], [17, 27], [37, 50]] returns an overlap of 33
# [[18, 26], [1, 23], [2, 42]] returns an overlap of 36
# [[13, 38], [18, 24], [41, 42], [8, 44], [16, 34]] returns an overlap of 6
# [[31, 40], [6, 17], [22, 30]] returns an overlap of 28
# [[15, 31], [46, 47], [12, 38], [24, 38]] returns an overlap of 20
# [[23, 44], [10, 35], [4, 42], [26, 33], [18, 38]] returns an overlap of -25
# [[2, 9], [4, 44], [27, 44], [9, 16], [36, 38]] returns an overlap of 40
# [[34, 50], [4, 7]] returns an overlap of 19
# [[13, 47], [20, 21], [16, 25]] returns an overlap of 33
# [[26, 41], [31, 43], [37, 38], [11, 20], [19, 49]] returns an overlap of 26
# [[10, 26], [3, 33]] returns an overlap of 30
# [[0, 11], [14, 19], [16, 25], [4, 48], [25, 49]] returns an overlap of 46
# [[0, 46], [32, 34], [22, 46], [8, 45], [11, 33]] returns an overlap of -15
# [[30, 46], [21, 44], [40, 49]] returns an overlap of 24
# [[19, 42], [2, 9], [5, 25], [12, 31], [39, 45]] returns an overlap of 37
# [[8, 47], [7, 9], [40, 43], [29, 42]] returns an overlap of 38
# [[27, 45], [21, 35], [0, 30]] returns an overlap of 42
# [[0, 33], [13, 47], [1, 29]] returns an overlap of 31
# [[37, 38], [28, 44], [8, 47]] returns an overlap of 38
# [[0, 39], [4, 27], [17, 18], [23, 31]] returns an overlap of 34
# [[2, 10], [8, 47], [33, 46], [5, 23]] returns an overlap of 43
# [[19, 33], [1, 41]] returns an overlap of 40
# [[1, 15], [22, 32], [6, 34], [6, 12], [40, 45]] returns an overlap of 32
# [[3, 42], [20, 50], [7, 29], [37, 45]] returns an overlap of 33
# [[22, 32], [20, 24], [18, 35]] returns an overlap of 15
# [[15, 49], [11, 44], [11, 22]] returns an overlap of 31
# [[15, 41], [10, 35], [19, 33]] returns an overlap of 17
# [[1, 8], [9, 17], [38, 45]] returns an overlap of 22
# [[2, 28], [6, 39], [9, 42], [0, 37], [18, 40]] returns an overlap of -77
# [[18, 45], [13, 41]] returns an overlap of 32
# [[11, 20], [39, 49], [32, 39], [3, 46], [38, 44]] returns an overlap of 40
# [[12, 36], [11, 44], [22, 45], [7, 11], [34, 44]] returns an overlap of 12
# [[7, 24], [0, 32], [20, 21], [5, 47]] returns an overlap of 28
# [[10, 16], [16, 24], [41, 44], [43, 44], [12, 33]] returns an overlap of 26
# [[36, 42], [3, 16]] returns an overlap of 19
# [[3, 20], [15, 32], [2, 47]] returns an overlap of 40
# [[26, 33], [9, 31], [38, 50], [7, 10]] returns an overlap of 38
# [[10, 26], [18, 26], [39, 45]] returns an overlap of 22
# [[21, 41], [9, 42], [3, 31], [17, 40]] returns an overlap of -4
# [[2, 7], [0, 31], [10, 14], [15, 24]] returns an overlap of 31
# [[18, 38], [36, 49], [15, 49], [20, 28]] returns an overlap of 24
# [[4, 21], [25, 43], [6, 12], [20, 34], [19, 49]] returns an overlap of 35
# [[24, 25], [40, 45]] returns an overlap of 6
# [[9, 46], [32, 38], [9, 18], [4, 36]] returns an overlap of 29
# [[34, 35], [7, 24], [7, 34], [41, 44]] returns an overlap of 31
# [[5, 34], [13, 18], [7, 15], [20, 21], [17, 47]] returns an overlap of 38
# [[3, 20], [20, 33], [24, 48]] returns an overlap of 45
# [[32, 37], [6, 23], [45, 45]] returns an overlap of 22
# [[33, 45], [15, 32], [40, 45], [12, 31]] returns an overlap of 32
# [[15, 27], [6, 14], [39, 49]] returns an overlap of 30
# [[4, 7], [3, 9], [1, 45], [6, 9]] returns an overlap of 37
# [[27, 38], [7, 37]] returns an overlap of 31
# [[28, 46], [1, 15], [0, 1], [10, 14]] returns an overlap of 33
# [[36, 50], [2, 40], [11, 41], [14, 47], [19, 33]] returns an overlap of -15
# [[0, 11], [50, 50], [7, 33]] returns an overlap of 33
# [[40, 45], [47, 50]] returns an overlap of 8
# [[6, 25], [13, 27], [13, 20], [42, 46]] returns an overlap of 18
# [[9, 50], [2, 7], [18, 24], [6, 42], [8, 45]] returns an overlap of 3
# [[16, 31], [2, 47], [17, 41], [20, 49], [4, 9]] returns an overlap of 1
# [[14, 24], [27, 31], [9, 34]] returns an overlap of 25
# [[42, 47], [2, 12], [16, 48], [35, 50], [33, 44]] returns an overlap of 28
# [[38, 49], [11, 33]] returns an overlap of 33
# [[18, 29], [25, 43]] returns an overlap of 25
# [[31, 43], [28, 44], [31, 43], [36, 42]] returns an overlap of -8
# [[10, 29], [4, 42], [27, 38]] returns an overlap of 36
# [[8, 16], [11, 32], [22, 26], [1, 27]] returns an overlap of 22
# [[25, 43], [20, 21], [0, 39], [17, 32], [7, 21]] returns an overlap of 30
# [[18, 30], [4, 21], [9, 28]] returns an overlap of 23
# [[0, 44], [10, 14], [10, 31], [4, 38]] returns an overlap of 15
# [[45, 49], [26, 41], [12, 46], [8, 36]] returns an overlap of 31
# [[3, 33], [27, 44], [27, 44], [0, 5]] returns an overlap of 38
# [[2, 8], [0, 11]] returns an overlap of 11
# [[10, 16], [4, 43], [17, 41], [13, 39], [20, 23]] returns an overlap of 8
# [[5, 18], [8, 22], [10, 26], [29, 31], [21, 30]] returns an overlap of 17
# [[11, 39], [20, 45]] returns an overlap of 34
# [[0, 9], [16, 24], [45, 48]] returns an overlap of 20
# [[5, 21], [16, 40], [28, 44], [22, 48]] returns an overlap of 31
# [[7, 41], [35, 36]] returns an overlap of 34
# [[1, 27], [20, 49], [5, 8], [15, 20], [15, 27]] returns an overlap of 36
# [[5, 31], [24, 29], [33, 45]] returns an overlap of 38
# [[42, 46], [5, 36], [41, 42], [37, 50]] returns an overlap of 44
# [[10, 22], [36, 50]] returns an overlap of 26
# [[42, 45], [17, 49], [1, 28]] returns an overlap of 48
# [[38, 47], [1, 37], [11, 48], [0, 32], [16, 30]] returns an overlap of -1
# [[23, 30], [8, 15], [37, 45], [35, 42], [14, 16]] returns an overlap of 25
# [[5, 34], [2, 8], [1, 23], [1, 46]] returns an overlap of 18
# [[10, 48], [11, 20], [7, 47]] returns an overlap of 32
# [[31, 43], [15, 15], [35, 49], [21, 23]] returns an overlap of 20
# [[44, 47], [2, 8], [22, 32]] returns an overlap of 19
# [[9, 17], [2, 37]] returns an overlap of 35
# [[11, 11], [28, 39], [30, 50], [5, 24], [4, 48]] returns an overlap of 37
# [[3, 20], [8, 15]] returns an overlap of 17
# [[26, 29], [1, 44], [8, 29]] returns an overlap of 40
# [[8, 15], [2, 29], [7, 46], [28, 31]] returns an overlap of 36
# [[33, 34], [48, 48], [2, 42], [13, 19]] returns an overlap of 40
# [[19, 33], [33, 41]] returns an overlap of 22
# [[0, 7], [19, 40], [29, 31]] returns an overlap of 28
# [[1, 4], [28, 37], [28, 39], [10, 36]] returns an overlap of 24
# [[5, 37], [21, 24], [8, 16], [15, 33]] returns an overlap of 28
# [[7, 34], [23, 29], [19, 37]] returns an overlap of 24
# [[17, 34], [7, 35]] returns an overlap of 28
# [[12, 46], [9, 25], [13, 32], [15, 48], [7, 49]] returns an overlap of -60
# [[12, 30], [7, 23], [9, 29], [26, 27], [22, 28]] returns an overlap of 3
# [[17, 18], [10, 11], [18, 23], [6, 24]] returns an overlap of 18
# [[15, 18], [12, 31], [18, 41]] returns an overlap of 29
# [[1, 50], [7, 8], [10, 46], [24, 50], [39, 40]] returns an overlap of 25
# [[8, 33], [7, 9], [2, 8], [11, 22], [18, 41]] returns an overlap of 35
# [[15, 35], [31, 35], [10, 14], [32, 34]] returns an overlap of 22
# [[49, 50], [25, 29]] returns an overlap of 5
# [[24, 34], [14, 48], [13, 47], [34, 44], [17, 24]] returns an overlap of 8
# [[21, 43], [14, 38], [5, 8], [13, 42]] returns an overlap of 16
# [[40, 45], [0, 44], [11, 22]] returns an overlap of 45
# [[17, 49], [8, 21], [9, 45], [15, 26]] returns an overlap of 22
# [[37, 45], [2, 25], [12, 34], [46, 48], [40, 46]] returns an overlap of 43
# [[10, 27], [2, 48], [1, 23]] returns an overlap of 34
# [[15, 33], [8, 36], [8, 16], [17, 28], [35, 36]] returns an overlap of 16
# [[14, 15], [2, 22], [45, 48], [38, 49], [1, 15]] returns an overlap of 31
# [[31, 43], [37, 41], [0, 21], [5, 10]] returns an overlap of 33
# [[18, 28], [5, 38], [33, 36], [36, 50], [28, 50]] returns an overlap of 40
# [[15, 49], [32, 33], [5, 44], [24, 39]] returns an overlap of 27
# [[20, 38], [23, 37], [36, 49]] returns an overlap of 28
# [[20, 28], [0, 27], [4, 11], [23, 29]] returns an overlap of 25
# [[15, 33], [4, 12], [13, 32], [35, 44], [5, 47]] returns an overlap of 26
# [[34, 50], [9, 25], [28, 40], [19, 33]] returns an overlap of 41
# [[11, 44], [9, 18], [16, 25], [3, 20], [13, 19]] returns an overlap of 14
# [[18, 22], [9, 34], [25, 28], [28, 37]] returns an overlap of 28
# [[10, 26], [17, 30]] returns an overlap of 20
# [[4, 9], [4, 14], [13, 19], [14, 30]] returns an overlap of 26
# [[23, 44], [8, 50], [6, 42]] returns an overlap of 25
# [[32, 46], [17, 27], [43, 48], [2, 42]] returns an overlap of 46
# [[21, 24], [23, 31], [38, 44], [25, 45]] returns an overlap of 24
# [[25, 43], [30, 36], [0, 5]] returns an overlap of 23
# [[16, 30], [0, 6], [4, 44]] returns an overlap of 44
# [[9, 17], [42, 45], [16, 47], [10, 35], [0, 6]] returns an overlap of 43
# [[33, 43], [9, 40], [25, 29], [22, 43]] returns an overlap of 23
# [[37, 50], [5, 11]] returns an overlap of 19
# [[11, 37], [9, 16]] returns an overlap of 28
